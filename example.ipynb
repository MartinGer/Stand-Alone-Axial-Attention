# %%
from fastai.vision.all import *
from Axial_Model import resnet50

# %%
CLASSES = 10

def prepare_data(img_size, batch_size):
    path = untar_data(URLs.IMAGENETTE_320)
    item_tfms=RandomResizedCrop(size=img_size, min_scale=0.8)
    batch_tfms=[*aug_transforms(flip_vert=False, max_lighting=0.2, max_rotate=15., max_zoom=1.1, max_warp=0.2, p_affine=0.75, p_lighting=0.75), 
                Normalize.from_stats(*imagenet_stats)]
    dls = ImageDataLoaders.from_folder(path, valid='val', item_tfms=item_tfms, batch_tfms=batch_tfms, bs=batch_size)  
    return dls

ds = prepare_data(224, 20)

# %%
ds.show_batch()

# %%
num_heads = 8
model = resnet50(num_classes=CLASSES, attention=[True,True,True,True], num_heads=num_heads)
learn = Learner(ds, model, opt_func=Adam, metrics=accuracy)

# %%
epochs = 1
lr = 1e-4
learn.fit(n_epoch=epochs, lr=lr, cbs=ReduceLROnPlateau(monitor='accuracy', min_delta=0.001, patience=10, factor=3, min_lr=1e-8))
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='8' class='' max='946' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.85% [8/946 00:04<08:47 2.5010]
#     </div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-d9c8bdf37e55> in <module>
#       1 epochs = 1
#       2 lr = 1e-4
# ----> 3 learn.fit(n_epoch=epochs, lr=lr, cbs=ReduceLROnPlateau(monitor='accuracy', min_delta=0.001, patience=10, factor=3, min_lr=1e-8))
#
# ~/anaconda3/envs/pytorch/lib/python3.8/site-packages/fastai/learner.py in fit(self, n_epoch, lr, wd, cbs, reset_opt)
#     209             self.opt.set_hypers(lr=self.lr if lr is None else lr)
#     210             self.n_epoch = n_epoch
# --> 211             self._with_events(self._do_fit, 'fit', CancelFitException, self._end_cleanup)
#     212
#     213     def _end_cleanup(self): self.dl,self.xb,self.yb,self.pred,self.loss = None,(None,),(None,),None,None
#
# ~/anaconda3/envs/pytorch/lib/python3.8/site-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     158
#     159     def _with_events(self, f, event_type, ex, final=noop):
# --> 160         try: self(f'before_{event_type}');  f()
#     161         except ex: self(f'after_cancel_{event_type}')
#     162         self(f'after_{event_type}');  final()
#
# ~/anaconda3/envs/pytorch/lib/python3.8/site-packages/fastai/learner.py in _do_fit(self)
#     200         for epoch in range(self.n_epoch):
#     201             self.epoch=epoch
# --> 202             self._with_events(self._do_epoch, 'epoch', CancelEpochException)
#     203
#     204     def fit(self, n_epoch, lr=None, wd=None, cbs=None, reset_opt=False):
#
# ~/anaconda3/envs/pytorch/lib/python3.8/site-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     158
#     159     def _with_events(self, f, event_type, ex, final=noop):
# --> 160         try: self(f'before_{event_type}');  f()
#     161         except ex: self(f'after_cancel_{event_type}')
#     162         self(f'after_{event_type}');  final()
#
# ~/anaconda3/envs/pytorch/lib/python3.8/site-packages/fastai/learner.py in _do_epoch(self)
#     194
#     195     def _do_epoch(self):
# --> 196         self._do_epoch_train()
#     197         self._do_epoch_validate()
#     198
#
# ~/anaconda3/envs/pytorch/lib/python3.8/site-packages/fastai/learner.py in _do_epoch_train(self)
#     186     def _do_epoch_train(self):
#     187         self.dl = self.dls.train
# --> 188         self._with_events(self.all_batches, 'train', CancelTrainException)
#     189
#     190     def _do_epoch_validate(self, ds_idx=1, dl=None):
#
# ~/anaconda3/envs/pytorch/lib/python3.8/site-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     158
#     159     def _with_events(self, f, event_type, ex, final=noop):
# --> 160         try: self(f'before_{event_type}');  f()
#     161         except ex: self(f'after_cancel_{event_type}')
#     162         self(f'after_{event_type}');  final()
#
# ~/anaconda3/envs/pytorch/lib/python3.8/site-packages/fastai/learner.py in all_batches(self)
#     164     def all_batches(self):
#     165         self.n_iter = len(self.dl)
# --> 166         for o in enumerate(self.dl): self.one_batch(*o)
#     167
#     168     def _do_one_batch(self):
#
# ~/anaconda3/envs/pytorch/lib/python3.8/site-packages/fastai/learner.py in one_batch(self, i, b)
#     182         self.iter = i
#     183         self._split(b)
# --> 184         self._with_events(self._do_one_batch, 'batch', CancelBatchException)
#     185
#     186     def _do_epoch_train(self):
#
# ~/anaconda3/envs/pytorch/lib/python3.8/site-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     158
#     159     def _with_events(self, f, event_type, ex, final=noop):
# --> 160         try: self(f'before_{event_type}');  f()
#     161         except ex: self(f'after_cancel_{event_type}')
#     162         self(f'after_{event_type}');  final()
#
# ~/anaconda3/envs/pytorch/lib/python3.8/site-packages/fastai/learner.py in _do_one_batch(self)
#     177         self.loss_grad.backward()
#     178         self._with_events(self.opt.step, 'step', CancelStepException)
# --> 179         self.opt.zero_grad()
#     180
#     181     def one_batch(self, i, b):
#
# ~/anaconda3/envs/pytorch/lib/python3.8/site-packages/fastai/optimizer.py in zero_grad(self)
#      76         for p,*_ in self.all_params(with_grad=True):
#      77             p.grad.detach_()
# ---> 78             p.grad.zero_()
#      79
#      80     def step(self):
#
# ~/anaconda3/envs/pytorch/lib/python3.8/site-packages/torch/tensor.py in grad(self)
#     940         """
#     941         relevant_args = (self,)
# --> 942         from torch.overrides import has_torch_function, handle_torch_function
#     943         if type(self) is not Tensor and has_torch_function(relevant_args):
#     944             # TODO mypy doesn't support @property, see: https://github.com/python/mypy/issues/6185
#
# KeyboardInterrupt:
